# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2 from pathlib import Path
#       4 # Current directory (where the script is located)
# ----> 5 data_dir = Path(__file__).parent
#       7 # Loop through all CSV files in this directory
#       8 for file_path in data_dir.glob("*.csv"):
#
# NameError: name '__file__' is not defined
